# %% [markdown]
# # Part a) Qubit Basics, Gates, Bell States & Entanglement (15 pt)
#
# **FYS5419 – Quantum Computing and Quantum Machine Learning, Project 1**
#
# ---
#
# ## Objectives
#
# 1. Set up a one-qubit basis and apply Pauli matrices ($\sigma_x, \sigma_y, \sigma_z$)
# 2. Apply Hadamard and Phase gates to one-qubit basis states
# 3. Define Bell states
# 4. Implement Hadamard + CNOT on a Bell state, perform repeated measurements on each qubit
# 5. Trace out the density matrix for one subsystem and compute the von Neumann entropy
#
# ---

# %%
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. One-Qubit Basis & Pauli Matrices

# %%
# TODO: Define |0> and |1> basis states
# TODO: Define Pauli matrices sigma_x, sigma_y, sigma_z
# TODO: Apply each Pauli matrix to |0> and |1>, display results

# %% [markdown]
# ## 2. Hadamard & Phase Gates

# %%
# TODO: Define the Hadamard gate H
# TODO: Define the Phase gate S
# TODO: Apply H and S to |0> and |1>, display results

# %% [markdown]
# ## 3. Bell States

# %%
# TODO: Define the four Bell states
# |Phi+> = (|00> + |11>) / sqrt(2)
# |Phi-> = (|00> - |11>) / sqrt(2)
# |Psi+> = (|01> + |10>) / sqrt(2)
# |Psi-> = (|01> - |10>) / sqrt(2)

# %% [markdown]
# ## 4. Hadamard + CNOT on a Bell State & Measurements

# %%
# TODO: Choose one Bell state
# TODO: Apply Hadamard gate to first qubit
# TODO: Apply CNOT gate
# TODO: Perform repeated measurements on qubit 1, then qubit 2
# TODO: Compute and discuss average measurement results

# %% [markdown]
# ## 5. Density Matrix & von Neumann Entropy

# %%
# TODO: Construct density matrix rho = |psi><psi|
# TODO: Trace out subsystem B to get rho_A
# TODO: Compute von Neumann entropy S = -Tr(rho_A * log2(rho_A))
# TODO: Discuss results (pure vs entangled)

# %% [markdown]
# ## Discussion
#
# *TODO: Summarize findings and discuss the results.*
