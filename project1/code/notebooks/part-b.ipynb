# %% [markdown]
# # Part b) One-Qubit Hamiltonian – Eigenvalue Problem (10 pt)
#
# **FYS5419 – Quantum Computing and Quantum Machine Learning, Project 1**
#
# ---
#
# ## Objectives
#
# 1. Set up the 2x2 Hamiltonian $H = H_0 + \lambda H_I$
# 2. Rewrite $H_0$ and $H_I$ in terms of Pauli matrices and identity
# 3. Solve the eigenvalue problem using standard eigenvalue solvers
# 4. Find eigenvalues as a function of interaction strength $\lambda \in [0, 1]$
# 5. Study and comment on the behavior of eigenstates
#
# ### Parameters
# - $E_1 = 0$, $E_2 = 4$
# - $V_{11} = -V_{22} = 3$, $V_{12} = V_{21} = 0.2$
#
# ---

# %%
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Define the Hamiltonian

# %%
# Parameters
E1 = 0.0
E2 = 4.0
V11 = 3.0
V22 = -3.0
V12 = 0.2
V21 = 0.2

# TODO: Construct H_0 and H_I matrices
# TODO: Express in terms of Pauli matrices

# %% [markdown]
# ## 2. Pauli Matrix Decomposition
#
# $$H_0 = \mathcal{E} I + \Omega \sigma_z$$
# $$H_I = c I + \omega_z \sigma_z + \omega_x \sigma_x$$

# %%
# TODO: Compute epsilon, Omega, c, omega_z, omega_x
# TODO: Verify the Pauli decomposition matches the matrix form

# %% [markdown]
# ## 3. Eigenvalues as a Function of $\lambda$

# %%
# TODO: Sweep lambda from 0 to 1
# TODO: Solve H(lambda) = H_0 + lambda * H_I for each lambda
# TODO: Store eigenvalues and eigenvectors

# %% [markdown]
# ## 4. Plot & Analysis

# %%
# TODO: Plot eigenvalues vs lambda
# TODO: Discuss the level crossing at lambda = 2/3
# TODO: Study eigenvector composition as function of lambda

# %% [markdown]
# ## Discussion
#
# *TODO: Comment on the behavior of eigenvalues and eigenstates, especially the interchange of character at $\lambda = 2/3$.*
