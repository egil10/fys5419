# %% [markdown]
# # Part c) VQE for the One-Qubit Hamiltonian (10 pt)
#
# **FYS5419 – Quantum Computing and Quantum Machine Learning, Project 1**
#
# ---
#
# ## Objectives
#
# 1. Implement the Variational Quantum Eigensolver (VQE) for the 2x2 Hamiltonian from Part b
# 2. Set up the necessary quantum circuit(s)
# 3. Find eigenvalues using VQE
# 4. Compare with exact results from Part b
# 5. Write your own VQE code (may compare with Qiskit/Pennylane)
#
# ---

# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Hamiltonian Setup (from Part b)

# %%
# TODO: Import or redefine the Hamiltonian H(lambda) from Part b

# %% [markdown]
# ## 2. Ansatz Circuit

# %%
# TODO: Define a parameterized ansatz for a single qubit
# e.g., |psi(theta)> = Ry(theta)|0>

# %% [markdown]
# ## 3. Expectation Value Computation

# %%
# TODO: Compute <psi(theta)|H|psi(theta)>
# TODO: Decompose into Pauli expectation values

# %% [markdown]
# ## 4. VQE Optimization

# %%
# TODO: Use scipy.optimize.minimize to find optimal theta
# TODO: Sweep over lambda values
# TODO: Store VQE eigenvalues

# %% [markdown]
# ## 5. Comparison with Exact Results

# %%
# TODO: Plot VQE eigenvalues vs exact eigenvalues (from Part b)
# TODO: Compute and plot errors

# %% [markdown]
# ## Discussion
#
# *TODO: Discuss VQE accuracy, convergence, choice of ansatz, and comparison with Part b.*
