# %% [markdown]
# # Part d) Two-Qubit System – Entanglement & von Neumann Entropy (15 pt)
#
# **FYS5419 – Quantum Computing and Quantum Machine Learning, Project 1**
#
# ---
#
# ## Objectives
#
# 1. Extend to a two-qubit system with subsystems A and B
# 2. Set up the 4x4 Hamiltonian: $H = H_0 + \lambda H_I$ with $H_I = H_x \sigma_x \otimes \sigma_x + H_z \sigma_z \otimes \sigma_z$
# 3. Solve eigenvalue problem with standard solvers as function of $\lambda$
# 4. Compute density matrices and trace out subsystem
# 5. Calculate von Neumann entropy and study entanglement
#
# ### Parameters
# - $H_x = 2.0$, $H_z = 3.0$
# - Non-interacting energies: $\epsilon_{00} = 0.0$, $\epsilon_{10} = 2.5$, $\epsilon_{01} = 6.5$, $\epsilon_{11} = 7.0$
#
# ---

# %%
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Two-Qubit Computational Basis

# %%
# TODO: Define |00>, |01>, |10>, |11> basis states via tensor products

# %% [markdown]
# ## 2. Hamiltonian Construction

# %%
Hx = 2.0
Hz = 3.0
energies = [0.0, 2.5, 6.5, 7.0]  # eps_00, eps_10, eps_01, eps_11

# TODO: Construct the 4x4 Hamiltonian matrix
# TODO: Include H_0 (diagonal) and H_I (sigma_x x sigma_x + sigma_z x sigma_z terms)

# %% [markdown]
# ## 3. Eigenvalues vs $\lambda$

# %%
# TODO: Sweep lambda from 0 to 1
# TODO: Diagonalize H(lambda) = H_0 + lambda * H_I
# TODO: Plot all four eigenvalues as functions of lambda

# %% [markdown]
# ## 4. Density Matrix & Partial Trace

# %%
# TODO: Construct density matrix rho_0 for the ground state
# TODO: Compute rho_A = Tr_B(rho_0) and rho_B = Tr_A(rho_0)

# %% [markdown]
# ## 5. von Neumann Entropy & Entanglement

# %%
# TODO: Compute S(A) = -Tr(rho_A * log2(rho_A)) as function of lambda
# TODO: Plot entropy vs lambda
# TODO: Identify the level crossing and discuss entanglement behavior

# %% [markdown]
# ## Discussion
#
# *TODO: Discuss the role of entanglement, the entropy jump at the level crossing, and how entanglement is driven by the Hamiltonian interaction strengths.*
