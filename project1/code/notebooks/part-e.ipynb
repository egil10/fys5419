# %% [markdown]
# # Part e) VQE for the Two-Qubit System (15 pt)
#
# **FYS5419 – Quantum Computing and Quantum Machine Learning, Project 1**
#
# ---
#
# ## Objectives
#
# 1. Implement VQE for the two-qubit Hamiltonian from Part d
# 2. Set up the two-qubit ansatz circuit
# 3. Find the lowest eigenvalue using VQE
# 4. Compare with exact results from Part d
# 5. Write your own VQE code (may compare with Qiskit/Pennylane)
#
# ---

# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Hamiltonian Setup (from Part d)

# %%
# TODO: Import or redefine the 4x4 Hamiltonian H(lambda) from Part d

# %% [markdown]
# ## 2. Two-Qubit Ansatz Circuit

# %%
# TODO: Define a parameterized two-qubit ansatz
# e.g., Ry(theta1) x Ry(theta2) followed by CNOT and additional rotations

# %% [markdown]
# ## 3. Expectation Value Computation

# %%
# TODO: Compute <psi(theta)|H|psi(theta)>
# TODO: Decompose Hamiltonian into Pauli strings for measurement

# %% [markdown]
# ## 4. VQE Optimization

# %%
# TODO: Optimize parameters using scipy.optimize.minimize
# TODO: Sweep over lambda values
# TODO: Store VQE ground state energies

# %% [markdown]
# ## 5. Comparison with Exact Results

# %%
# TODO: Plot VQE eigenvalues vs exact eigenvalues (from Part d)
# TODO: Compute and plot relative errors
# TODO: Optionally compare with Qiskit/Pennylane VQE

# %% [markdown]
# ## Discussion
#
# *TODO: Discuss circuit depth, ansatz expressibility, optimizer performance, and agreement with exact solution.*
