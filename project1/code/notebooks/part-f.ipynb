# %% [markdown]
# # Part f) Lipkin Model – Classical Diagonalization (15 pt)
#
# **FYS5419 – Quantum Computing and Quantum Machine Learning, Project 1**
#
# ---
#
# ## Objectives
#
# 1. Introduce the Lipkin Hamiltonian $H = H_0 + H_1 + H_2$
# 2. Rewrite in terms of quasispin operators ($J_z, J_+, J_-$)
# 3. For $J = 1$ ($N = 2$ particles, $W = 0$): set up the 3x3 Hamiltonian and express in Pauli matrices
# 4. For $J = 2$ ($N = 4$ particles, $W = 0$): set up the 5x5 Hamiltonian and express in Pauli matrices
# 5. Diagonalize classically and find eigenvalues as functions of the interaction strength $V$
# 6. (Challenge) Include the $W$ term
#
# ### Reference
# - [Phys. Rev. C 106, 024319](https://journals.aps.org/prc/pdf/10.1103/PhysRevC.106.024319)
#
# ---

# %%
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Lipkin Model – Theory
#
# $$H_0 = \varepsilon J_z, \quad H_1 = \frac{1}{2} V (J_+^2 + J_-^2), \quad H_2 = \frac{1}{2} W (-N + J_+ J_- + J_- J_+)$$

# %% [markdown]
# ## 2. J = 1 Case (3x3 Matrix, W = 0)

# %%
# TODO: Construct the 3x3 Hamiltonian for J=1
# H_{J=1} = [[-eps, 0, -V], [0, 0, 0], [-V, 0, eps]]
# TODO: Rewrite in terms of Pauli matrices (N=2 particles, so 2 qubits)

# %% [markdown]
# ## 3. J = 2 Case (5x5 Matrix, W = 0)

# %%
# TODO: Construct the 5x5 Hamiltonian for J=2
# TODO: Rewrite in terms of Pauli matrices (N=4 particles)
# (Challenge: also include the W term)

# %% [markdown]
# ## 4. Classical Diagonalization

# %%
# TODO: Sweep interaction strength V (keeping epsilon fixed)
# TODO: Diagonalize H_{J=1} and H_{J=2} for each V
# TODO: Store eigenvalues

# %% [markdown]
# ## 5. Plots & Analysis

# %%
# TODO: Plot eigenvalues vs V for J=1 and J=2
# TODO: Optionally add Hartree-Fock results
# TODO: Comment on level crossings and structure

# %% [markdown]
# ## Discussion
#
# *TODO: Comment on the eigenvalue structure, compare J=1 and J=2 results, discuss the role of the interaction strength V.*
