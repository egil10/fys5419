# %% [markdown]
# # Part g) VQE for the Lipkin Model (20 pt)
#
# **FYS5419 – Quantum Computing and Quantum Machine Learning, Project 1**
#
# ---
#
# ## Objectives
#
# 1. Apply the VQE method to the Lipkin Hamiltonians from Part f
# 2. Set up circuits and simulations for both J=1 and J=2 cases
# 3. Find the eigenvalues using VQE
# 4. Compare with exact classical results from Part f
# 5. Discuss circuit design, accuracy, and scalability
#
# ---

# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Hamiltonian Setup (from Part f)

# %%
# TODO: Import or redefine Lipkin Hamiltonians in Pauli form from Part f
# TODO: Set up Pauli string decomposition for J=1 and J=2

# %% [markdown]
# ## 2. Ansatz Circuit – J = 1

# %%
# TODO: Design an appropriate ansatz for the J=1 (2-qubit) Lipkin model
# TODO: Consider symmetry-preserving ansatze

# %% [markdown]
# ## 3. VQE for J = 1

# %%
# TODO: Run VQE optimization for J=1 Lipkin model
# TODO: Sweep interaction strength V
# TODO: Store VQE eigenvalues

# %% [markdown]
# ## 4. Ansatz Circuit – J = 2

# %%
# TODO: Design an appropriate ansatz for the J=2 (3-qubit) Lipkin model
# TODO: Consider encoding the 5x5 Hamiltonian into 3 qubits (8 states, 5 used)

# %% [markdown]
# ## 5. VQE for J = 2

# %%
# TODO: Run VQE optimization for J=2 Lipkin model
# TODO: Sweep interaction strength V
# TODO: Store VQE eigenvalues

# %% [markdown]
# ## 6. Comparison with Exact Results

# %%
# TODO: Plot VQE vs exact eigenvalues for both J=1 and J=2
# TODO: Compute and display errors
# TODO: Optionally compare with Qiskit/Pennylane implementations

# %% [markdown]
# ## Discussion
#
# *TODO: Discuss VQE performance for Lipkin model, circuit depth requirements, encoding challenges for J=2, and comparison with Part f exact results.*
