# %% [markdown]
# # SNP

# %% [markdown]
# ### IMPORTS

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from scripts.snp import SNP

# %% [markdown]
# ### DATA

# %%
snp = SNP(["AAPL", "MSFT", "AMZN", "GOOG"], "2020-01-01", "2023-12-31")
snp.fetch()
snp.summary()
snp.plot()

mu, Sigma = snp.mu, snp.Sigma
# Out:
# ✓ 1006 1d obs for ['AAPL', 'MSFT', 'AMZN', 'GOOG'] (2020-01-02 → 2023-12-29)
#
# 4 assets, 1006 1d obs
# Ticker     Ann.Ret   Ann.Vol    Sharpe
# AAPL        24.26%    33.55%     0.723
# MSFT        22.26%    32.63%     0.682
# AMZN        11.80%    37.68%     0.313
# GOOG        18.14%    33.51%     0.541
