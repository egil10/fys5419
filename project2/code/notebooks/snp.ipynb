# %% [markdown]
# # SNP

# %% [markdown]
# ### IMPORTS

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

# %load_ext autoreload
# %autoreload 2

from scripts.snp import SNP
from scripts.baskets import get, BASKETS

# %% [markdown]
# ### DATA

# %%
# single basket — first run fetches + caches, later runs load from disk
snp = SNP(get("mag7"), "2020-01-01", "2023-12-31").cached_fetch(name="mag7")
snp.summary()
snp.plot(save=True)

# %%
# loop over all baskets
for name, info in BASKETS.items():
    snp = SNP(info["tickers"], "2020-01-01", "2023-12-31").cached_fetch(name=name)
    snp.summary()
