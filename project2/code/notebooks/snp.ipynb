# %% [markdown]
# # SNP

# %% [markdown]
# ### IMPORTS

# %%
import sys

from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from scripts.snp import SNP
from scripts.baskets import get, BASKETS, config

# %% [markdown]
# ### DATA

# %%
for name in BASKETS:
    tickers, start, end = config(name)
    snp = SNP(tickers, start, end).cached_fetch(name=name)
    snp.summary()
    snp.plot(save=True, name=name)
# Out:
# ✓ cached → data\mag7.parquet
#
# 4 assets, 1006 1d obs
# Ticker     Ann.Ret   Ann.Vol    Sharpe
# AAPL        24.26%    33.55%     0.723
# MSFT        22.26%    32.63%     0.682
# GOOGL       17.89%    33.58%     0.533
# AMZN        11.80%    37.68%     0.313
# ✓ saved → plots\eda\mag7_overview.pdf
# ✓ cached → data\quantum.parquet
#
# 4 assets, 608 1d obs
# Ticker     Ann.Ret   Ann.Vol    Sharpe
# IONQ        88.53%    91.88%     0.964
# RGTI        58.94%   139.19%     0.423
# QBTS         2.44%   144.94%     0.017
# QUBT        71.78%   129.03%     0.556
# ✓ saved → plots\eda\quantum_overview.pdf
# ✓ cached → data\quantum_big.parquet
#
# 4 assets, 1006 1d obs
# Ticker     Ann.Ret   Ann.Vol    Sharpe
# IBM         10.80%    27.61%     0.391
# HON          5.78%    29.02%     0.199
# GOOGL       17.89%    33.58%     0.533
# NVDA        53.03%    53.88%     0.984
# ✓ saved → plots\eda\quantum_big_overview.pdf
# ✓ 1006 1d obs for ['XOM', 'DAL', 'NEM', 'JPM'] (2020-01-02 → 2023-12-29)
# ✓ cached → C:\Users\ofurn\Dokumenter\Github\fys5419\project2\code\data\anti.parquet
#
# 4 assets, 1006 1d obs
# Ticker     Ann.Ret   Ann.Vol    Sharpe
# XOM         13.86%    37.24%     0.372
# DAL         -9.32%    52.63%    -0.177
# NEM          2.28%    36.70%     0.062
# JPM          7.72%    34.36%     0.225
# ✓ saved → plots\eda\anti_overview.pdf

# %% [markdown]
# ### BASKETS

# %%
# single basket — first run fetches + caches, later runs load from disk
snp = SNP(get("mag7"), "2020-01-01", "2023-12-31").cached_fetch(name="mag7")
snp.summary()
snp.plot(save=True, name="mag7")
# Out:
# ✓ cached → data\mag7.parquet
#
# 4 assets, 1006 1d obs
# Ticker     Ann.Ret   Ann.Vol    Sharpe
# AAPL        24.26%    33.55%     0.723
# MSFT        22.26%    32.63%     0.682
# GOOGL       17.89%    33.58%     0.533
# AMZN        11.80%    37.68%     0.313
# ✓ saved → plots\eda\mag7_overview.pdf

# %%
# single basket — first run fetches + caches, later runs load from disk
snp = SNP(get("quantum"), "2020-01-01", "2023-12-31").cached_fetch(name="quantum")
snp.summary()
snp.plot(save=True, name="quantum")
# Out:
# ✓ cached → data\quantum.parquet
#
# 4 assets, 608 1d obs
# Ticker     Ann.Ret   Ann.Vol    Sharpe
# IONQ        88.53%    91.88%     0.964
# RGTI        58.94%   139.19%     0.423
# QBTS         2.44%   144.94%     0.017
# QUBT        71.78%   129.03%     0.556
# ✓ saved → plots\eda\quantum_overview.pdf

# %%
# single basket — first run fetches + caches, later runs load from disk
snp = SNP(get("quantum_big"), "2020-01-01", "2023-12-31").cached_fetch(name="quantum_big")
snp.summary()
snp.plot(save=True, name="quantum_big")
# Out:
# ✓ cached → data\quantum_big.parquet
#
# 4 assets, 1006 1d obs
# Ticker     Ann.Ret   Ann.Vol    Sharpe
# IBM         10.80%    27.61%     0.391
# HON          5.78%    29.02%     0.199
# GOOGL       17.89%    33.58%     0.533
# NVDA        53.03%    53.88%     0.984
# ✓ saved → plots\eda\quantum_big_overview.pdf

# %%
# single basket — first run fetches + caches, later runs load from disk
snp = SNP(get("anti"), "2020-01-01", "2023-12-31").cached_fetch(name="anti")
snp.summary()
snp.plot(save=True, name="anti")
# Out:
# ✓ cached → data\anti.parquet
#
# 4 assets, 1006 1d obs
# Ticker     Ann.Ret   Ann.Vol    Sharpe
# XOM         13.86%    37.24%     0.372
# DAL         -9.32%    52.63%    -0.177
# NEM          2.28%    36.70%     0.062
# JPM          7.72%    34.36%     0.225
# ✓ saved → plots\eda\anti_overview.pdf
