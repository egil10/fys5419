# %% [markdown]
# # SNP

# %% [markdown]
# ### IMPORTS

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from scripts.snp import SNP

# %% [markdown]
# ### DATA

# %%
snp = SNP(["AAPL", "MSFT", "AMZN", "GOOG"], "2020-01-01", "2023-12-31")
snp.fetch()
snp.summary()

# one combined 4x2 grid, saved as code/project2/plots/eda/overview.pdf
snp.plot(save=True)

# OR each panel as its own PDF in plots/eda/
# snp.plot(save=True, individual=True)

mu, Sigma = snp.mu, snp.Sigma
