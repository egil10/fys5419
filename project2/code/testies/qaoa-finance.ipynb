# %% [markdown]
# # QAOA FINANCE

# %% [markdown]
# $$ \text{Financial Data} \rightarrow (\mu, \Sigma) \rightarrow \text{Ising Hamiltonian} \rightarrow \text{Pauli operators} \rightarrow \text{QAOA} $$

# %% [markdown]
# ### IMPORTS

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import expm
from scipy.optimize import minimize
from itertools import product

np.random.seed(42)

# %% [markdown]
# ### MEAN-VARIANCE-PORTFOLIO-OPTIMIZATION

# %% [markdown]
# $$ \min_x \left( -\mu^\top x + \lambda x ^\top \Sigma x \right) \quad \lambda > 0 \quad  \sum_{i=1}^{n} x_i = K  $$

# %% [markdown]
# $$ C(x) = -\mu^\top x + \lambda x^\top \Sigma x + A \left( \sum_{i=1}^{n} x_i - K \right)^2 $$

# %% [markdown]
# $$ r_i(t) = \frac{P_i(t+1) - P_i(t)}{P_i(t)} \approx \ln\frac{P_i(t+1)}{P_i(t)} $$

# %% [markdown]
# $$ \mu_i=\langle r_i \rangle _t \quad \Sigma_{ij} = \langle r_ir_j \rangle - \langle r_i \rangle \langle r_j \rangle $$
